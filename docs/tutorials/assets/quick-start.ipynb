# %% [markdown]
# # Install mage_ai

# %%
# %pip install mage-ai
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Users/dangerous/Code/materia/mage-ai/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import libraries

# %%
import mage_ai

# %% [markdown]
# # Load data

# %%
from mage_ai.server.sample_datasets import list_dataset_names, load_dataset


dataset_names = list_dataset_names()
print(dataset_names)
df = load_dataset('titanic_survival.csv')
# Out:
# ['titanic_survival.csv', 'salary_survey.csv', 'user_emails.csv', 'product_purchases.csv']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Connect data to app

# %%
mage_ai.connect_df(df, 'titanic survival dataset')
# Out:
# [time] metric: data_cleaner.infer_column_types, value: 27ms, tags: {}
# [time] metric: data_cleaner.clean_series, value: 11ms, tags: {}
# [time] metric: data_cleaner.calculate_statistics, value: 17ms, tags: {}
# [time] metric: data_cleaner.calculate_insights, value: 32ms, tags: {}
# [time] metric: data_cleaner.create_suggested_actions, value: 25ms, tags: {}
# (<mage_ai.server.data.models.FeatureSet at 0x1558c7130>,
#       PassengerId  Survived  Pclass  \
#  0              1         0       3
#  1              2         1       1
#  2              3         1       3
#  3              4         1       1
#  4              5         0       3
#  ..           ...       ...     ...
#  886          887         0       2
#  887          888         1       1
#  888          889         0       3
#  889          890         1       1
#  890          891         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# ...

# %% [markdown]
# # Run app locally

# %%
mage_ai.kill() # Kill any previously running instance
mage_ai.launch()
# Out:
#  * Serving Flask app 'mage_ai.server.app' (lazy loading)
#  * Environment: production
#         <iframe
#             width="95%"
#             height="1000"
#             src="http://localhost:5789"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
# <ThreadWithTrace(Thread-18, started daemon 13122789376)>
#  * Debug mode: off

# %% [markdown]
# # Clean data using pipeline created from app

# %%
mage_ai.clean(df, pipeline_uuid=1)
# Out:
# Pipeline is empty.
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...
